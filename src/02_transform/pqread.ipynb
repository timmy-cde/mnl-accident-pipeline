# %%
import pandas as pd

# %%
BUCKET_NAME="mnl_accident_pipeline_bucket"
CLEANED_FOLDER_NAME="cleaned_v2"

fname = f"gs://{BUCKET_NAME}/{CLEANED_FOLDER_NAME}/date=2026-04-03/*.parquet"

# %%
df = pd.read_parquet(fname, engine="pyarrow")
